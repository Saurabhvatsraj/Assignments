# %%
import pandas as pd
import numpy as  np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\Dell\tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.shape
# Out:
# (418, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
len(df)
# Out:
# 418

# %%
per_of_missingvalue=df.isnull().sum()/len(df)*100
per_of_missingvalue
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
# show null value in percentage form
plt.title("Percentage of null value:",fontsize=15)
per_of_missingvalue[per_of_missingvalue!=0].plot(figsize=(6,4),kind='barh')
plt.xlabel("Percentage",fontsize=10)
plt.ylabel("Columns  Name",fontsize=10)
# Out:
# Text(0, 0.5, 'Columns  Name')

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#total fare of male and female
sns.scatterplot(x=df["Fare"], y=df["Sex"])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Sex'>

# %%
#max fare by female

# %%
# total fare on the bases of survived
sns.scatterplot(x=df["Fare"], y=df["Survived"])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Survived'>

# %%
# total fare on the bases of class
sns.scatterplot(x=df["Fare"], y=df["Pclass"])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Pclass'>

# %%
#total fare om the bases of fare
sns.scatterplot(x=df["Fare"], y=df["Embarked"])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Embarked'>

# %%
# see distribuation of top 20 age
plt.plot(df['Age'].head(20))

# %%
# total count of embarked
x=df['Embarked'].value_counts()
x
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
x.plot(figsize=(8,6),kind='pie',autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='Embarked'>
